# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('https://www.worldometers.info/coronavirus/', 'html.parser')
soup = requests.get(url)
soup
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7564\3880274233.py:3: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   url = BeautifulSoup('https://www.worldometers.info/coronavirus/', 'html.parser')
# <Response [200]>

# %%
code = BeautifulSoup(soup.text, "lxml")
table_code = code.table
table_code
# Out:
# <table class="table table-bordered table-hover main_table_countries" id="main_table_countries_today" style="width:100%;margin-top: 0px !important;display:none;">
# <thead>
# <tr>
# <th width="1%">#</th>
# <th width="100">Country,<br/>Other</th>
# <th width="20">Total<br/>Cases</th>
# <th width="30">New<br/>Cases</th>
# <th width="30">Total<br/>Deaths</th>
# <th width="30">New<br/>Deaths</th>
# <th width="30">Total<br/>Recovered</th>
# <th width="30">New<br/>Recovered</th>
# <th width="30">Active<br/>Cases</th>
# <th width="30">Serious,<br/>Critical</th>
# <th width="30">Tot Cases/<br/>1M pop</th>
# <th width="30">Deaths/<br/>1M pop</th>
# <th width="30">Total<br/>Tests</th>
# <th width="30">Tests/<br/>
# <nobr>1M pop</nobr>
# </th>
# <th width="30">Population</th>
# <th style="display:none" width="30">Continent</th>
# <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
# <th width="30">New Cases/1M pop</th>
# ...

# %%
tags = table_code.find_all('tr')
tags
# Out:
# [<tr>
#  <th width="1%">#</th>
#  <th width="100">Country,<br/>Other</th>
#  <th width="20">Total<br/>Cases</th>
#  <th width="30">New<br/>Cases</th>
#  <th width="30">Total<br/>Deaths</th>
#  <th width="30">New<br/>Deaths</th>
#  <th width="30">Total<br/>Recovered</th>
#  <th width="30">New<br/>Recovered</th>
#  <th width="30">Active<br/>Cases</th>
#  <th width="30">Serious,<br/>Critical</th>
#  <th width="30">Tot Cases/<br/>1M pop</th>
#  <th width="30">Deaths/<br/>1M pop</th>
#  <th width="30">Total<br/>Tests</th>
#  <th width="30">Tests/<br/>
#  <nobr>1M pop</nobr>
#  </th>
#  <th width="30">Population</th>
#  <th style="display:none" width="30">Continent</th>
#  <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
#  <th width="30">New Cases/1M pop</th>
#  <th width="30">New Deaths/1M pop</th>
#  <th width="30">Active Cases/1M pop</th>
#  </tr>,
# ...

# %%
data = []
for tag in tags:
  y = tag.text.split('\n')[1:]
  if y[0] != "":
    data.append(y)

# %%
import csv
file = open('covid_data.csv','w')
x = csv.writer(file)
x.writerows(data)
file.close()

# %%
import pandas as pd
df = pd.read_csv('covid_data.csv',encoding = 'latin1')
df
# Out:
#        #   Country,Other   TotalCases  NewCases  \
# 0      1             USA  110,109,948       NaN
# 1      2           India   45,013,272       NaN
# 2      3          France   40,138,560       NaN
# 3      4         Germany   38,765,656       NaN
# 4      5          Brazil   38,177,375       NaN
# ..   ...             ...          ...       ...
# 226  227         Tokelau           80       NaN
# 227  228    Vatican City           29       NaN
# 228  229  Western Sahara           10       NaN
# 229  230      MS Zaandam            9       NaN
# 230  231           China      503,302       NaN
#
#                                    TotalDeaths  NewDeaths TotalRecovered  \
# 0    1,190,171                                        NaN    107,887,617
# 1      533,361                                        NaN            NaN
# 2      167,642                                        NaN     39,970,918
# 3      180,109                                        NaN     38,240,600
# ...

# %%
# !pip install plotly==5.18.0

# %%
df = df[['Country,Other','TotalCases','TotalDeaths']].dropna()
df = df.iloc[0:20]
df
# Out:
#    Country,Other   TotalCases                                TotalDeaths
# 0            USA  110,109,948  1,190,171
# 1          India   45,013,272    533,361
# 2         France   40,138,560    167,642
# 3        Germany   38,765,656    180,109
# 4         Brazil   38,177,375    708,491
# 5       S. Korea   34,571,873     35,934
# 6          Japan   33,803,572     74,694
# 7          Italy   26,632,429    194,768
# 8             UK   24,812,582    232,112
# 9         Russia   23,713,738    401,214
# 10        Turkey   17,232,066    102,174
# 11         Spain   13,914,811    121,760
# 12     Australia   11,745,723     23,808
# 13       Vietnam   11,624,114     43,206
# 14        Taiwan   10,241,523     19,005
# 15     Argentina   10,080,046    130,685
# 16   Netherlands    8,623,210     22,992
# 17        Mexico    7,702,731    334,947
# 18          Iran    7,625,292    146,751
# 19     Indonesia    6,819,830    161,954

# %%
df['TotalCases'] = list( map(lambda x : int( x.replace(',','')),df['TotalCases'])) # removes , from the TotalCases
df['TotalDeaths'] = list( map(lambda x : int( x.replace(',','')),df['TotalDeaths'])) # removes , from the TotalDeaths
df
# Out:
#    Country,Other  TotalCases  TotalDeaths
# 0            USA   110109948      1190171
# 1          India    45013272       533361
# 2         France    40138560       167642
# 3        Germany    38765656       180109
# 4         Brazil    38177375       708491
# 5       S. Korea    34571873        35934
# 6          Japan    33803572        74694
# 7          Italy    26632429       194768
# 8             UK    24812582       232112
# 9         Russia    23713738       401214
# 10        Turkey    17232066       102174
# 11         Spain    13914811       121760
# 12     Australia    11745723        23808
# 13       Vietnam    11624114        43206
# 14        Taiwan    10241523        19005
# 15     Argentina    10080046       130685
# 16   Netherlands     8623210        22992
# 17        Mexico     7702731       334947
# 18          Iran     7625292       146751
# 19     Indonesia     6819830       161954

# %%
import plotly.express as px
fig = px.bar(df, x='Country,Other', y='TotalCases')
fig.show()
# Out:
# <div>                            <div id="748bcd1f-2f2e-4568-8f4c-1166f725b731" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("748bcd1f-2f2e-4568-8f4c-1166f725b731")) {                    Plotly.newPlot(                        "748bcd1f-2f2e-4568-8f4c-1166f725b731",                        [{"alignmentgroup":"True","hovertemplate":"Country,Other=%{x}\u003cbr\u003eTotalCases=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia","Turkey","Spain","Australia","Vietnam","Taiwan","Argentina","Netherlands","Mexico","Iran","In
# ...

# %%
import plotly.express as px
fig = px.bar(df, x='Country,Other', y='TotalDeaths')
fig.show()
# Out:
# <div>                            <div id="62aa2b88-6553-445b-b89b-43038c8654dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62aa2b88-6553-445b-b89b-43038c8654dc")) {                    Plotly.newPlot(                        "62aa2b88-6553-445b-b89b-43038c8654dc",                        [{"alignmentgroup":"True","hovertemplate":"Country,Other=%{x}\u003cbr\u003eTotalDeaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["USA","India","France","Germany","Brazil","S. Korea","Japan","Italy","UK","Russia","Turkey","Spain","Australia","Vietnam","Taiwan","Argentina","Netherlands","Mexico","Iran","I
# ...
