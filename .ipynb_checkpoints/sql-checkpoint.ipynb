# %%
# !Pip install mysql-connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.9 MB 445.2 kB/s eta 0:00:27
#      --------------------------------------- 0.0/11.9 MB 281.8 kB/s eta 0:00:42
#      --------------------------------------- 0.1/11.9 MB 365.7 kB/s eta 0:00:33
#      --------------------------------------- 0.1/11.9 MB 383.3 kB/s eta 0:00:31
#      --------------------------------------- 0.1/11.9 MB 350.1 kB/s eta 0:00:34
#      --------------------------------------- 0.1/11.9 MB 364.4 kB/s eta 0:00:33
#      --------------------------------------- 0.1/11.9 MB 361.0 kB/s eta 0:00:33
#      --------------------------------------- 0.1/11.9 MB 355.0 kB/s eta 0:00:33
#       -------------------------------------- 0.2/11.9 MB 378.3 kB/s eta 0:00:31
#       -------------------------------------- 0.2/11.9 MB 361.7 kB/s eta 0:00:33
# ...

# %%
import mysql.connector  #importing database
database = mysql.connector.connect(
    host = "localhost",
    user ="root",
    password = "",
    database = "python 3 pm"
)
db = database.cursor()

# %%
sql = "select * from student"
db.execute(sql)
result = db.fetchall()
print(result)
# Out:
# [(1, 'rajesh', 80, 90, 85, 60, 90, 560, 78.0, 'f'), (2, 'laxmi', 80, 90, 97, 95, 70, 600, 80.0, 'p')]

# %%
sql = "select sn,name,total,per,grade from student"
db.execute(sql)
result = db.fetchall()
print(result)
# Out:
# [(1, 'rajesh', 560, 78.0, 'f'), (2, 'laxmi', 600, 80.0, 'p')]

# %%
sql = "select * from student where grade = 'p'"
db.execute(sql)
result = db.fetchall()
print(result)
# Out:
# [(2, 'laxmi', 80, 90, 97, 95, 70, 600, 80.0, 'p')]

# %%
# insert
sql = '''INSERT INTO `student` ( Name, Physics, Chemistry, Math, English, Nepali, total, Per, Grade) VALUES ( 'santosh', 50, 50, 50, 50, 50, 250, 50, 'p');'''
db.execute(sql)
database.commit()

# %%
# wap to create a result management system takeing data from user and store it in database

# %%
#update
sql = "Update student SET name = 'purnima' where sn = 4"
db. execute(sql)
database.commit()

# %%
# delete
sql = "delete from student where sn = 3"
db.execute(sql)
database.commit()

# %%
import sqlite3
def create database():
    conn = sqlite3.connect("results.db")
    cursor = conn.cursor()
    
    cursor.execute("""CREATE TABLE IF NOT EXISTS students
    ( roll number INTEGER PRIMARY KEY,
    name TEXT,
    marks INTEGER
    )""")
conn.commit()
conn.close()
def insert result(roll number ,name ,marks):
    conn = sqlite3.connect("results.db")
    cursor = conn.cursor()
    
    cursor.execute("INSERT INTO students VALUES (?, ?, ?)",
                   (roll number ,name, marks ))
    conn.commit()
    conn.close()
def displays results():
    conn = sqlite3.connect("results.db")
    cursor = conn.cursor()
    
    cursor.execute("SELECT * FROM students")
    results = cursor.fetchall()
    
     for result in results:
        print("roll number:", result[0])
        print("name:",result[1])
        print("marks:",result[2])
        print("---------------")
        conn.close()
def store result():
    roll number = int(input("enter roll number : "))
    name = input("enter name : ")
    marks = int(input("enter marks : "))
    
    insert result (roll number , name , marks)
    print("result stored sucessfully")
    
if name == "main":
    create database()
    
    while true:
        print("1.store results")
        print("2. display results")
        print("3.exit")
        
        choice = int(input("enter your choice(1-3): "))
        
        if choice == 1:
            store result()
        elif choice == 2:
            display results()
        elif choice == 3:
            break
        else:
            print("invalid choice please try again.")
        print()
# Out:
#   Cell In[9], line 2
#     def create database():
#                ^
# SyntaxError: expected '('
